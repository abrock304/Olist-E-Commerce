# %% [markdown]
# # Brazilian E-Commerce
# ### Data Understanding

# %%
# Import Libraries

import pandas as pd
import numpy as np
import os
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# Import data for dataframe via path
path = r'/Users/abrockk12.wv.us/Documents/Career Foundry/Brazilian E_Commerce'
path
# Out:
# '/Users/abrockk12.wv.us/Documents/Career Foundry/Brazilian E_Commerce'

# %%
customers = pd.read_csv(os.path.join(path, 'olist_customers_dataset.csv'))

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.shape
# Out:
# (99441, 5)

# %%
customers.rename(columns = {'customer_zip_code_prefix':'zip_code_prefix'}, inplace = True)

# %%
cust_dup = customers[customers.duplicated()]
cust_dup
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
customers.isnull().sum()
# Out:
# customer_id           0
# customer_unique_id    0
# zip_code_prefix       0
# customer_city         0
# customer_state        0
# dtype: int64

# %%
location = pd.read_csv(os.path.join(path, 'olist_geolocation_dataset.csv'))

# %%
location.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
location.shape
# Out:
# (1000163, 5)

# %%
locate_dups = location[location.duplicated()]
locate_dups
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 15                              1046       -23.546081       -46.644820
# 44                              1046       -23.546081       -46.644820
# 65                              1046       -23.546081       -46.644820
# 66                              1009       -23.546935       -46.636588
# 67                              1046       -23.546081       -46.644820
# ...                              ...              ...              ...
# 1000153                        99970       -28.343273       -51.873734
# 1000154                        99950       -28.070493       -52.011342
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 15             sao paulo                SP
# ...

# %%
location = location.drop_duplicates()

# %%
location.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
location.rename(columns={'geolocation_zip_code_prefix':'zip_code_prefix'}, inplace = True)

# %%
location2 = location
location2
# Out:
#          zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 0                   1037       -23.545621       -46.639292        sao paulo
# 1                   1046       -23.546081       -46.644820        sao paulo
# 2                   1046       -23.546129       -46.642951        sao paulo
# 3                   1041       -23.544392       -46.639499        sao paulo
# 4                   1035       -23.541578       -46.641607        sao paulo
# ...                  ...              ...              ...              ...
# 1000155            99965       -28.180655       -52.034367       agua santa
# 1000156            99950       -28.072188       -52.011272         tapejara
# 1000157            99950       -28.068864       -52.012964         tapejara
# 1000158            99950       -28.068639       -52.010705         tapejara
# 1000161            99980       -28.388932       -51.846871  david canabarro
#
#         geolocation_state
# 0                      SP
# ...

# %%
location2 = location.drop(columns = ['geolocation_lat', 'geolocation_lng'])
location2
# Out:
#          zip_code_prefix geolocation_city geolocation_state
# 0                   1037        sao paulo                SP
# 1                   1046        sao paulo                SP
# 2                   1046        sao paulo                SP
# 3                   1041        sao paulo                SP
# 4                   1035        sao paulo                SP
# ...                  ...              ...               ...
# 1000155            99965       agua santa                RS
# 1000156            99950         tapejara                RS
# 1000157            99950         tapejara                RS
# 1000158            99950         tapejara                RS
# 1000161            99980  david canabarro                RS
#
# [738332 rows x 3 columns]

# %%
location_clean = location2.drop_duplicates()
location_clean
# Out:
#          zip_code_prefix      geolocation_city geolocation_state
# 0                   1037             sao paulo                SP
# 1                   1046             sao paulo                SP
# 3                   1041             sao paulo                SP
# 4                   1035             sao paulo                SP
# 5                   1012             são paulo                SP
# ...                  ...                   ...               ...
# 999806             99940                ibiaçá                RS
# 999846             99952  santa cecilia do sul                RS
# 999867             99970               ciríaco                RS
# 999891             99930               estação                RS
# 1000046            99955          vila lângaro                RS
#
# [27912 rows x 3 columns]

# %%
order_items = pd.read_csv(os.path.join(path, 'olist_order_items_dataset.csv'))

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
# missing values
order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
# Check for duplicates
order_items_dups = order_items[order_items.duplicated('order_id')]
order_items_dups
# Out:
#                                 order_id  order_item_id  \
# 14      0008288aa423d2a3f00fcb17cd7d8719              2
# 33      00143d0f86d6fbd9f9b38ab440ac16f5              2
# 34      00143d0f86d6fbd9f9b38ab440ac16f5              3
# 43      001ab0a7578dd66cd4b0a71f5b6e1e41              2
# 44      001ab0a7578dd66cd4b0a71f5b6e1e41              3
# ...                                  ...            ...
# 112617  ffecd5a79a0084f6a592288c67e3c298              3
# 112635  fff8287bbae429a99bb7e8c21d151c41              2
# 112641  fffb9224b6fc7c43ebb0904318b10b5f              2
# 112642  fffb9224b6fc7c43ebb0904318b10b5f              3
# 112643  fffb9224b6fc7c43ebb0904318b10b5f              4
#
#                               product_id                         seller_id  \
# 14      368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# 33      e95ee6822b66ac6058e2e4aff656071a  a17f621c590ea0fab3d5d883e1630ec6
# ...

# %%
order_items.nunique()
# Out:
# order_id               98666
# order_item_id             21
# product_id             32951
# seller_id               3095
# shipping_limit_date    93318
# price                   5968
# freight_value           6999
# dtype: int64

# %%
order_items.shape
# Out:
# (112650, 7)

# %%
order_payments = pd.read_csv(os.path.join(path, 'olist_order_payments_dataset.csv'))

# %%
order_payments.nunique()
# Out:
# order_id                99440
# payment_sequential         29
# payment_type                5
# payment_installments       24
# payment_value           29077
# dtype: int64

# %%
order_payments.shape
# Out:
# (103886, 5)

# %%
order_payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_payments_dups = order_payments[order_payments.duplicated('order_id')]
order_payments_dups
# Out:
#                                 order_id  payment_sequential payment_type  \
# 1456    683bf306149bb869980b68d48a1bd6ab                   1  credit_card
# 2324    e6a66a8350bb88497954d37688ab123e                   2      voucher
# 2393    8e5148bee82a7e42c5f9ba76161dc51a                   1  credit_card
# 2414    816ccd9d21435796e8ffa9802b2a782f                   1  credit_card
# 2497    2cbcb371aee438c59b722a21d83597e0                   2      voucher
# ...                                  ...                 ...          ...
# 103778  fd86c80924b4be8fb7f58c4ecc680dae                   1  credit_card
# 103817  6d4616de4341417e17978fe57aec1c46                   1  credit_card
# 103860  31bc09fdbd701a7a4f9b55b5955b8687                   6      voucher
# 103869  c9b01bef18eb84888f0fd071b8413b38                   1  credit_card
# 103874  d41f1036712e18ee525939d08b7a1c98                   1  credit_card
#
#         payment_installments  payment_value
# ...

# %%
order_reviews = pd.read_csv(os.path.join(path, 'olist_order_reviews_dataset.csv'))

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order_reviews.shape
# Out:
# (99224, 7)

# %%
order_reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
review_dups = order_reviews[order_reviews.duplicated()]
review_dups
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
order_reviews.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
orders = pd.read_csv(os.path.join(path, 'olist_orders_dataset.csv'))

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.shape
# Out:
# (99441, 8)

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
order_dups = orders[orders.duplicated()]
order_dups
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
check_total = orders[orders['order_id'] == '001ab0a7578dd66cd4b0a71f5b6e1e41']
check_total
# Out:
#                                order_id                       customer_id  \
# 26976  001ab0a7578dd66cd4b0a71f5b6e1e41  8bb3bef4e75a95524235cdc11a7331af
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 26976    delivered      2017-12-27 00:38:47  2017-12-28 02:33:42
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 26976          2017-12-28 18:09:35           2018-01-17 20:43:29
#
#       order_estimated_delivery_date
# 26976           2018-01-29 00:00:00

# %%
products = pd.read_csv(os.path.join(path, 'olist_products_dataset.csv'))

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products.shape
# Out:
# (32951, 9)

# %%
products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products.dropna(subset = ['product_category_name'], inplace = True)

# %%
products.rename(columns = {'product_name_lenght':'product_name_length','product_description_lenght': 'product_description_length' }, inplace = True)

# %%
products_dups = products[products.duplicated()]
products_dups
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_length, product_description_length, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
sellers = pd.read_csv(os.path.join(path, 'olist_sellers_dataset.csv'))

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.shape
# Out:
# (3095, 4)

# %%
sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
seller_dups = sellers[sellers.duplicated()]
seller_dups
# Out:
# Empty DataFrame
# Columns: [seller_id, seller_zip_code_prefix, seller_city, seller_state]
# Index: []

# %%
product_category = pd.read_csv(os.path.join(path, 'product_category_name_translation.csv'))

# %%
product_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
product_category.shape
# Out:
# (71, 2)

# %%
product_category.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
product_dups = product_category[product_category.duplicated()]
product_dups
# Out:
# Empty DataFrame
# Columns: [product_category_name, product_category_name_english]
# Index: []

# %%
closed_deals = pd.read_csv(os.path.join(path, 'olist_closed_deals_dataset.csv'))

# %%
closed_deals.head()
# Out:
#                              mql_id                         seller_id  \
# 0  5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1  a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2  327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3  f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4  ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
#
#                              sdr_id                             sr_id  \
# 0  a8387c01a09e99ce014107505b92388c  4ef15afb4b2723d8f3d81e51ec7afefe
# 1  09285259593c61296eef10c734121d5b  d3d1e91a157ea7f90548eef82f1955e3
# 2  b90f87164b5f8c2cfa5c8572834dbe3f  6565aa9ce3178a5caf6171827af3a9ba
# 3  56bf83c4bb35763a51c2baab501b4c67  d3d1e91a157ea7f90548eef82f1955e3
# 4  4b339f9567d060bcea4f5136b9f5949e  d3d1e91a157ea7f90548eef82f1955e3
#
#               won_date business_segment      lead_type lead_behaviour_profile  \
# ...

# %%
closed_deals.shape
# Out:
# (842, 14)

# %%
closed_deals.isnull().sum()
# Out:
# mql_id                             0
# seller_id                          0
# sdr_id                             0
# sr_id                              0
# won_date                           0
# business_segment                   1
# lead_type                          6
# lead_behaviour_profile           177
# has_company                      779
# has_gtin                         778
# average_stock                    776
# business_type                     10
# declared_product_catalog_size    773
# declared_monthly_revenue           0
# dtype: int64

# %%
closed_dups = closed_deals[closed_deals.duplicated()]
closed_dups
# Out:
# Empty DataFrame
# Columns: [mql_id, seller_id, sdr_id, sr_id, won_date, business_segment, lead_type, lead_behaviour_profile, has_company, has_gtin, average_stock, business_type, declared_product_catalog_size, declared_monthly_revenue]
# Index: []

# %%
marketing_qualified_leads = pd.read_csv(os.path.join(path, 'olist_marketing_qualified_leads_dataset.csv'))

# %%
marketing_qualified_leads.head()
# Out:
#                              mql_id first_contact_date  \
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21
#
#                     landing_page_id          origin
# 0  88740e65d5d6b056e0cda098e1ea6313          social
# 1  007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2  a7982125ff7aa3b2054c6e44f9d28522  organic_search
# 3  d45d558f0daeecf3cccdffe3c59684aa           email
# 4  b48ec5f3b04e9068441002a19df93c6c  organic_search

# %%
marketing_qualified_leads.shape
# Out:
# (8000, 4)

# %%
marketing_qualified_leads.isnull().sum()
# Out:
# mql_id                 0
# first_contact_date     0
# landing_page_id        0
# origin                60
# dtype: int64

# %%
market_dups = marketing_qualified_leads[marketing_qualified_leads.duplicated()]
market_dups
# Out:
# Empty DataFrame
# Columns: [mql_id, first_contact_date, landing_page_id, origin]
# Index: []

# %% [markdown]
# ### Merge All Tables Into One

# %%
# Merge order_items and order_payments on order_id
df = order_items.merge(order_payments, how = 'left', indicator = False)

# %%
df.shape
# Out:
# (117604, 11)

# %%
df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  payment_sequential  \
# 0  2017-09-19 09:45:35   58.90          13.29                 1.0
# 1  2017-05-03 11:05:13  239.90          19.93                 1.0
# ...

# %%
df_dups = df[df.duplicated(['order_id'])]
df_dups
# Out:
#                                 order_id  order_item_id  \
# 14      0008288aa423d2a3f00fcb17cd7d8719              2
# 33      00143d0f86d6fbd9f9b38ab440ac16f5              2
# 34      00143d0f86d6fbd9f9b38ab440ac16f5              3
# 39      0016dfedd97fc2950e388d2971d718c7              1
# 44      001ab0a7578dd66cd4b0a71f5b6e1e41              2
# ...                                  ...            ...
# 117571  ffecd5a79a0084f6a592288c67e3c298              3
# 117589  fff8287bbae429a99bb7e8c21d151c41              2
# 117595  fffb9224b6fc7c43ebb0904318b10b5f              2
# 117596  fffb9224b6fc7c43ebb0904318b10b5f              3
# 117597  fffb9224b6fc7c43ebb0904318b10b5f              4
#
#                               product_id                         seller_id  \
# 14      368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# 33      e95ee6822b66ac6058e2e4aff656071a  a17f621c590ea0fab3d5d883e1630ec6
# ...

# %%
df_2 = df.merge(order_reviews, how = 'left')
df_2
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118305  fffc94f6ce00a00581880bf54a75a037              1
# 118306  fffcd46ef2263f404302a634eb57f7eb              1
# 118307  fffce4705a9662cd70adb13d4a31832d              1
# 118308  fffe18544ffabc95dfada21779c9644f              1
# 118309  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_dups2 = df_2[df_2.duplicated(['order_id'])]
df_dups
# Out:
#                                 order_id  order_item_id  \
# 14      0008288aa423d2a3f00fcb17cd7d8719              2
# 33      00143d0f86d6fbd9f9b38ab440ac16f5              2
# 34      00143d0f86d6fbd9f9b38ab440ac16f5              3
# 39      0016dfedd97fc2950e388d2971d718c7              1
# 44      001ab0a7578dd66cd4b0a71f5b6e1e41              2
# ...                                  ...            ...
# 117571  ffecd5a79a0084f6a592288c67e3c298              3
# 117589  fff8287bbae429a99bb7e8c21d151c41              2
# 117595  fffb9224b6fc7c43ebb0904318b10b5f              2
# 117596  fffb9224b6fc7c43ebb0904318b10b5f              3
# 117597  fffb9224b6fc7c43ebb0904318b10b5f              4
#
#                               product_id                         seller_id  \
# 14      368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# 33      e95ee6822b66ac6058e2e4aff656071a  a17f621c590ea0fab3d5d883e1630ec6
# ...

# %%
df_3 = df_2.merge(orders, how = 'left')
df_3
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118305  fffc94f6ce00a00581880bf54a75a037              1
# 118306  fffcd46ef2263f404302a634eb57f7eb              1
# 118307  fffce4705a9662cd70adb13d4a31832d              1
# 118308  fffe18544ffabc95dfada21779c9644f              1
# 118309  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_4 = df_3.merge(products, how = 'left')
df_4
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118305  fffc94f6ce00a00581880bf54a75a037              1
# 118306  fffcd46ef2263f404302a634eb57f7eb              1
# 118307  fffce4705a9662cd70adb13d4a31832d              1
# 118308  fffe18544ffabc95dfada21779c9644f              1
# 118309  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_5 = df_4.merge(sellers, how = 'left')
df_5
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118305  fffc94f6ce00a00581880bf54a75a037              1
# 118306  fffcd46ef2263f404302a634eb57f7eb              1
# 118307  fffce4705a9662cd70adb13d4a31832d              1
# 118308  fffe18544ffabc95dfada21779c9644f              1
# 118309  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_6 = df_5.merge(customers, how = 'left')
df_6
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118305  fffc94f6ce00a00581880bf54a75a037              1
# 118306  fffcd46ef2263f404302a634eb57f7eb              1
# 118307  fffce4705a9662cd70adb13d4a31832d              1
# 118308  fffe18544ffabc95dfada21779c9644f              1
# 118309  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_7 = df_6.merge(product_category, how = 'left')
df_7
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118305  fffc94f6ce00a00581880bf54a75a037              1
# 118306  fffcd46ef2263f404302a634eb57f7eb              1
# 118307  fffce4705a9662cd70adb13d4a31832d              1
# 118308  fffe18544ffabc95dfada21779c9644f              1
# 118309  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_8 = df_7.merge(closed_deals, how = 'left')
df_8
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118305  fffc94f6ce00a00581880bf54a75a037              1
# 118306  fffcd46ef2263f404302a634eb57f7eb              1
# 118307  fffce4705a9662cd70adb13d4a31832d              1
# 118308  fffe18544ffabc95dfada21779c9644f              1
# 118309  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_9 = df_8.merge(marketing_qualified_leads, how = 'left')
df_9
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 118305  fffc94f6ce00a00581880bf54a75a037              1
# 118306  fffcd46ef2263f404302a634eb57f7eb              1
# 118307  fffce4705a9662cd70adb13d4a31832d              1
# 118308  fffe18544ffabc95dfada21779c9644f              1
# 118309  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_10 = df_9.merge(location_clean, how = 'left')
df_10
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       00018f77f2f0320c557190d7a144bdd3              1
# 3       000229ec398224ef6ca0657da4fc703e              1
# 4       000229ec398224ef6ca0657da4fc703e              1
# ...                                  ...            ...
# 177470  fffcd46ef2263f404302a634eb57f7eb              1
# 177471  fffce4705a9662cd70adb13d4a31832d              1
# 177472  fffce4705a9662cd70adb13d4a31832d              1
# 177473  fffe18544ffabc95dfada21779c9644f              1
# 177474  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_10.isnull().sum()
# Out:
# order_id                              0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    6
# payment_type                          6
# payment_installments                  6
# payment_value                         6
# review_id                          1469
# review_score                       1469
# review_comment_title             156583
# review_comment_message           103434
# review_creation_date               1469
# review_answer_timestamp            1469
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    24
# order_delivered_carrier_date       1919
# order_delivered_customer_date      3856
# ...

# %%
df_10_dups = df_10[df_10.duplicated()]
df_10_dups
# Out:
# Empty DataFrame
# ...

# %%
df_10_dups2 = df_10[df_10.duplicated(subset=['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'customer_id', 'customer_unique_id'])]
df_10_dups2
# Out:
#                                 order_id  order_item_id  \
# 2       00018f77f2f0320c557190d7a144bdd3              1
# 4       000229ec398224ef6ca0657da4fc703e              1
# 20      000aed2e25dbad2f9ddb70584c5a2ded              1
# 21      000aed2e25dbad2f9ddb70584c5a2ded              1
# 23      000c3e6612759851cc3cbb4b83257986              1
# ...                                  ...            ...
# 177455  fff8287bbae429a99bb7e8c21d151c41              1
# 177457  fff8287bbae429a99bb7e8c21d151c41              2
# 177459  fff90cdcb3b2e6cfb397d05d562fd3fe              1
# 177469  fffc94f6ce00a00581880bf54a75a037              1
# 177472  fffce4705a9662cd70adb13d4a31832d              1
#
#                               product_id                         seller_id  \
# 2       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 4       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# ...

# %%
clean = df_10.drop_duplicates(subset=['order_id', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'customer_id', 'customer_unique_id'])
clean
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 3       000229ec398224ef6ca0657da4fc703e              1
# 5       00024acbcdf0a6daa1e931b038114c75              1
# 6       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 177468  fffc94f6ce00a00581880bf54a75a037              1
# 177470  fffcd46ef2263f404302a634eb57f7eb              1
# 177471  fffce4705a9662cd70adb13d4a31832d              1
# 177473  fffe18544ffabc95dfada21779c9644f              1
# 177474  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
clean.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value', 'payment_sequential',
#        'payment_type', 'payment_installments', 'payment_value', 'review_id',
#        'review_score', 'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'customer_id',
#        'order_status', 'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'product_category_name',
#        'product_name_length', 'product_description_length',
#        'product_photos_qty', 'product_weight_g', 'product_length_cm',
#        'product_height_cm', 'product_width_cm', 'seller_zip_code_prefix',
#        'seller_city', 'seller_state', 'customer_unique_id', 'zip_code_prefix',
#        'customer_city', 'customer_state', 'product_category_name_english',
# ...

# %%
# Check for mixed variable types
for col in clean.columns.tolist():
    weird = (clean[[col]].applymap(type) != clean[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (clean[weird]) > 0:
        print (col)
# Out:
# review_creation_date
# review_answer_timestamp
# order_approved_at
# order_delivered_carrier_date
# order_delivered_customer_date
# first_contact_date

# %%
clean = clean.drop(columns = ['won_date', 'has_company', 'has_gtin', 'average_stock'])

# %%
clean['landing_page_id'].value_counts()
# Out:
# landing_page_id
# nan                                 107606
# b76ef37428e6799c421989521c0e5077      1331
# 22c29808c4f815213303f8933030604c      1149
# 40dec9f3d5259a3d2dbcdab2114fae47       452
# ce1a65abd0973638f1c887a6efcfa82d       357
#                                      ...
# 21a104c3279681d9856b8a48723c4fee         1
# df99f969c517db441d373ae68b2955c9         1
# 27cd3540bace1f4a4b2bc6d319b0553c         1
# 3e3371f8470ce094c7c82c09b7bd59d9         1
# 1e884e3078d9978e216a027ecd57fb34         1
# Name: count, Length: 76, dtype: int64

# %%
clean['business_type'] = clean['business_type'].astype(str)

# %%
clean['product_category_name_english'] = clean['product_category_name_english'].astype(str)

# %%
clean['mql_id'] = clean['mql_id'].astype(str)

# %%
clean['sr_id'] = clean['sr_id'].astype(str)

# %%
clean['business_segment'] = clean['business_segment'].astype(str)

# %%
clean['lead_type'] = clean['lead_type'].astype(str)

# %%
clean['lead_behaviour_profile'] = clean['lead_behaviour_profile'].astype(str)

# %%
clean['payment_type'] = clean['payment_type'].astype(str)

# %%
clean['review_id'] = clean['review_id'].astype(str)

# %%
clean['review_comment_title'] = clean['review_comment_title'].astype(str)

# %%
clean['review_comment_message'] = clean['review_comment_message'].astype(str)

# %%
clean['review_creation_date'] = pd.to_datetime(clean['review_creation_date'])

# %%
clean['review_answer_timestamp'] = pd.to_datetime(clean['review_answer_timestamp'])

# %%
clean['order_approved_at'] = pd.to_datetime(clean['order_approved_at'])

# %%
clean['order_delivered_carrier_date'] = pd.to_datetime(clean['order_delivered_carrier_date'])

# %%
clean['product_category_name'] = clean['product_category_name'].astype(str)

# %%
clean['order_delivered_customer_date'] = pd.to_datetime(clean['order_delivered_customer_date'])

# %%
clean['sdr_id'] = clean['sdr_id'].astype(str)

# %%
clean['first_contact_date'] = pd.to_datetime(clean['first_contact_date'])

# %%
clean['landing_page_id'] = clean['landing_page_id'].astype(str)

# %%
clean['origin'] = clean['origin'].astype(str)

# %%
clean['geolocation_city'] = clean['geolocation_city'].astype(str)

# %%
clean['geolocation_state'] = clean['geolocation_state'].astype(str)

# %%
ecommerce = clean.drop(columns = ['order_delivered_carrier_date', 'order_delivered_customer_date',
       'order_estimated_delivery_date','product_name_length', 'product_description_length',
       'product_photos_qty', 'product_weight_g', 'product_length_cm',
       'product_height_cm', 'product_width_cm','mql_id', 'sdr_id', 'sr_id', 'won_date', 'business_segment', 'has_company'])
ecommerce
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 3       000229ec398224ef6ca0657da4fc703e              1
# 5       00024acbcdf0a6daa1e931b038114c75              1
# 6       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 177468  fffc94f6ce00a00581880bf54a75a037              1
# 177470  fffcd46ef2263f404302a634eb57f7eb              1
# 177471  fffce4705a9662cd70adb13d4a31832d              1
# 177473  fffe18544ffabc95dfada21779c9644f              1
# 177474  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# ### Descriptive Statistics On Clean and Merged Data

# %%
ecommerce.describe()
# Out:
#        order_item_id          price  freight_value  payment_sequential  \
# count  112650.000000  112650.000000  112650.000000       112647.000000
# mean        1.197834     120.653739      19.990320            1.022646
# std         0.705124     183.633928      15.806405            0.255772
# min         1.000000       0.850000       0.000000            1.000000
# 25%         1.000000      39.900000      13.080000            1.000000
# 50%         1.000000      74.990000      16.260000            1.000000
# 75%         1.000000     134.900000      21.150000            1.000000
# max        21.000000    6735.000000     409.680000           27.000000
#
#        payment_installments  payment_value   review_score  \
# count         112647.000000  112647.000000  111708.000000
# mean               3.003205     177.552766       4.033516
# std                2.796766     270.878508       1.387084
# min                0.000000       0.010000       1.000000
# ...

# %%
# statistics
price_stats = orders.merge(order_payments, how = 'left')
price_stats
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 103882  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 103883  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 103884  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 103885  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 103886  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
grouped = price_stats.groupby('order_id')

# %%
total_price = grouped['payment_value'].sum()
total_price
# Out:
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214     72.19
# 00018f77f2f0320c557190d7a144bdd3    259.83
# 000229ec398224ef6ca0657da4fc703e    216.87
# 00024acbcdf0a6daa1e931b038114c75     25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9    218.04
#                                      ...
# fffc94f6ce00a00581880bf54a75a037    343.40
# fffcd46ef2263f404302a634eb57f7eb    386.53
# fffce4705a9662cd70adb13d4a31832d    116.85
# fffe18544ffabc95dfada21779c9644f     64.71
# fffe41c64501cc87c801fd61db3f6244     55.79
# Name: payment_value, Length: 99441, dtype: float64

# %%
total_price.describe()
# Out:
# count    99441.000000
# mean       160.988648
# std        221.950728
# min          0.000000
# 25%         62.010000
# 50%        105.290000
# 75%        176.970000
# max      13664.080000
# Name: payment_value, dtype: float64

# %%
group2 = price_stats.groupby('payment_type')
payment_groups = group2['payment_value'].sum()
payment_groups
# Out:
# payment_type
# boleto          2869361.27
# credit_card    12542084.19
# debit_card       217989.79
# not_defined           0.00
# voucher          379436.87
# Name: payment_value, dtype: float64

# %%
payment_type_agg = ecommerce.groupby('payment_type', as_index = False).agg({'payment_value':'sum'})
payment_type_agg
# Out:
#   payment_type  payment_value
# 0       boleto     4059699.60
# 1  credit_card    15441319.66
# 2   debit_card      253463.86
# 3      voucher      246303.35

# %%
payment_groups_bar = sns.barplot(data = payment_type_agg, x = 'payment_type', y = 'payment_value')
# Out:
# /Users/abrockk12.wv.us/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/abrockk12.wv.us/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/abrockk12.wv.us/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Export Data
clean.to_pickle(os.path.join(path, 'e_commerce_clean.pkl'))
